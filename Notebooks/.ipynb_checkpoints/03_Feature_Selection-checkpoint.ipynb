# %% [markdown]
# # Feature Selection

# %%
import pandas as pd
import numpy as np

import pickle

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.anova import anova_lm

from scipy.stats import chi2_contingency
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
with open('../Data/after_feature_engineering.pkl', 'rb') as f:
    df_train = pickle.load(f)
    df_valid = pickle.load(f)
    df_test = pickle.load(f)
    df_train_encoded = pickle.load(f)
    df_valid_encoded = pickle.load(f)
    df_test_encoded = pickle.load(f)

df_train_encoded.head()
# Out:
#                  unit_id  dim_m2  n_rooms  floor_no  floor_max  year_built  \
# 45366   f13df795472bee05   59.39      3.0       3.0        4.0      1980.0
# 86630   003ffcbd3294c3c9   52.95      2.0       2.0        6.0      2023.0
# 139489  f5d1fc8f4a154cd4   24.55      2.0       2.0        4.0      1993.0
# 24126   02376da3fe009bb0   57.58      3.0       3.0        3.0      2017.0
# 151982  7b6bb74dcdff86a3   73.71      3.0       1.0        2.0      2016.0
#
#         dist_centre  n_poi  dist_sch  dist_clinic  ...  green_space_ratio  \
# 45366         2.578   19.0     0.326        0.462  ...              1.000
# 86630         8.413   13.0     0.387        1.423  ...              0.999
# 139489        4.479    2.0     0.561        0.611  ...              1.000
# 24126        13.367    0.0     1.195        3.004  ...              0.999
# 151982        9.365    0.0     2.159        4.349  ...              0.999
#
#         estimated_maintenance_cost  global_economic_index  obj_type_0d6c4dfc  \
# 45366                        17.98              93.327971                  0
# 86630                        24.08              94.280615                  1
# 139489                        9.25             108.618716                  1
# 24126                         8.48             100.635935                  0
# 151982                       24.94              93.385347                  0
#
#         obj_type_2a6d5c01 obj_type_Unknown build_mat_7f8c00f9  \
# 45366                   0                1                  0
# 86630                   0                0                  0
# 139489                  0                0                  0
# 24126                   0                1                  0
# 151982                  1                0                  0
#
#        build_mat_Unknown has_lift_no  has_lift_yes
# 45366                  1           1             0
# 86630                  1           0             1
# 139489                 1           1             0
# 24126                  1           0             1
# 151982                 0           0             1
#
# [5 rows x 36 columns]

# %%
quantitative_cols = df_train.select_dtypes(include=[np.number]).columns
quantitative_cols
# Out:
# Index(['dim_m2', 'n_rooms', 'floor_no', 'floor_max', 'year_built',
#        'dist_centre', 'n_poi', 'dist_sch', 'dist_clinic', 'dist_post',
#        'dist_kind', 'dist_rest', 'dist_uni', 'dist_pharma', 'price_z',
#        'market_volatility', 'infrastructure_quality',
#        'neighborhood_crime_rate', 'popularity_index', 'green_space_ratio',
#        'estimated_maintenance_cost', 'global_economic_index'],
#       dtype='object')

# %%
qualitative_cols = df_train.select_dtypes('object').columns
qualitative_cols
# Out:
# Index(['unit_id', 'obj_type', 'build_mat', 'has_park', 'has_balcony',
#        'has_lift', 'has_sec', 'has_store', 'src_month', 'loc_code'],
#       dtype='object')

# %%
numeric_correlations = df_train[quantitative_cols].corr(method = 'pearson')
numeric_correlations
# Out:
#                               dim_m2   n_rooms  floor_no  floor_max  \
# dim_m2                      1.000000  0.764844 -0.067437  -0.122041
# n_rooms                     0.764844  1.000000 -0.033562  -0.076970
# floor_no                   -0.067437 -0.033562  1.000000   0.684431
# floor_max                  -0.122041 -0.076970  0.684431   1.000000
# year_built                 -0.008315  0.002222  0.036390   0.079527
# dist_centre                 0.043345  0.051778 -0.035679  -0.038398
# n_poi                       0.031472  0.000570  0.042037   0.040131
# dist_sch                    0.062423  0.065951 -0.107016  -0.139825
# dist_clinic                 0.014807  0.039488 -0.133092  -0.181233
# dist_post                   0.051594  0.057016 -0.082681  -0.102438
# dist_kind                   0.064538  0.060783 -0.095813  -0.129223
# dist_rest                   0.029452  0.047444 -0.092955  -0.126647
# dist_uni                    0.039850  0.051577 -0.072701  -0.092989
# dist_pharma                 0.052812  0.059733 -0.108647  -0.135994
# price_z                     0.539520  0.475738  0.018018   0.043358
# market_volatility           0.549842  0.462929  0.025273   0.035807
# infrastructure_quality      0.011522  0.001110 -0.035104  -0.075598
# neighborhood_crime_rate    -0.000547 -0.000970 -0.002542   0.001806
# popularity_index           -0.000080 -0.002391 -0.002836  -0.003839
# green_space_ratio          -0.042473 -0.048711  0.023672   0.021144
# estimated_maintenance_cost  0.692743  0.529219 -0.047334  -0.087672
# global_economic_index      -0.016099 -0.013060  0.009317   0.012445
#
#                             year_built  dist_centre     n_poi  dist_sch  \
# dim_m2                       -0.008315     0.043345  0.031472  0.062423
# n_rooms                       0.002222     0.051778  0.000570  0.065951
# floor_no                      0.036390    -0.035679  0.042037 -0.107016
# floor_max                     0.079527    -0.038398  0.040131 -0.139825
# year_built                    1.000000     0.327439 -0.341724  0.243847
# dist_centre                   0.327439     1.000000 -0.448654  0.280865
# n_poi                        -0.341724    -0.448654  1.000000 -0.302385
# dist_sch                      0.243847     0.280865 -0.302385  1.000000
# dist_clinic                   0.233358     0.418226 -0.366946  0.556135
# dist_post                     0.219275     0.253783 -0.316574  0.747705
# dist_kind                     0.115257     0.130249 -0.205759  0.768516
# dist_rest                     0.156536     0.223125 -0.330543  0.760285
# dist_uni                      0.335137     0.531408 -0.442513  0.441463
# dist_pharma                   0.186528     0.244279 -0.295678  0.793242
# price_z                       0.155483     0.138251  0.151286  0.027947
# market_volatility             0.114435     0.081355  0.168293 -0.000319
# infrastructure_quality       -0.921149    -0.302203  0.315429 -0.224365
# neighborhood_crime_rate      -0.003277    -0.006379  0.003857 -0.003669
# popularity_index             -0.003161     0.005492 -0.001391 -0.000168
# green_space_ratio            -0.278373    -0.826239  0.311658 -0.276299
# estimated_maintenance_cost   -0.006414     0.030678  0.018242  0.042037
# global_economic_index         0.000248     0.012266 -0.004696 -0.001473
#
#                             dist_clinic  dist_post  ...  dist_uni  \
# dim_m2                         0.014807   0.051594  ...  0.039850
# n_rooms                        0.039488   0.057016  ...  0.051577
# floor_no                      -0.133092  -0.082681  ... -0.072701
# floor_max                     -0.181233  -0.102438  ... -0.092989
# year_built                     0.233358   0.219275  ...  0.335137
# dist_centre                    0.418226   0.253783  ...  0.531408
# n_poi                         -0.366946  -0.316574  ... -0.442513
# dist_sch                       0.556135   0.747705  ...  0.441463
# dist_clinic                    1.000000   0.492856  ...  0.504941
# dist_post                      0.492856   1.000000  ...  0.361494
# dist_kind                      0.442313   0.720038  ...  0.294494
# dist_rest                      0.509970   0.758203  ...  0.353027
# dist_uni                       0.504941   0.361494  ...  1.000000
# dist_pharma                    0.509734   0.791855  ...  0.377653
# price_z                       -0.086504   0.004152  ...  0.020074
# market_volatility             -0.101297  -0.011361  ... -0.014364
# infrastructure_quality        -0.215063  -0.201274  ... -0.309884
# neighborhood_crime_rate       -0.002069  -0.001685  ... -0.005784
# popularity_index              -0.000421   0.000995  ...  0.005220
# green_space_ratio             -0.383959  -0.231928  ... -0.485289
# estimated_maintenance_cost     0.009800   0.034485  ...  0.028777
# global_economic_index          0.005948  -0.002376  ...  0.002387
#
#                             dist_pharma   price_z  market_volatility  \
# dim_m2                         0.052812  0.539520           0.549842
# n_rooms                        0.059733  0.475738           0.462929
# floor_no                      -0.108647  0.018018           0.025273
# floor_max                     -0.135994  0.043358           0.035807
# year_built                     0.186528  0.155483           0.114435
# dist_centre                    0.244279  0.138251           0.081355
# n_poi                         -0.295678  0.151286           0.168293
# dist_sch                       0.793242  0.027947          -0.000319
# dist_clinic                    0.509734 -0.086504          -0.101297
# dist_post                      0.791855  0.004152          -0.011361
# dist_kind                      0.817864 -0.010204          -0.016647
# dist_rest                      0.822213 -0.084935          -0.094730
# dist_uni                       0.377653  0.020074          -0.014364
# dist_pharma                    1.000000  0.002697          -0.013971
# price_z                        0.002697  1.000000           0.909009
# market_volatility             -0.013971  0.909009           1.000000
# infrastructure_quality        -0.171352 -0.143008          -0.104882
# neighborhood_crime_rate       -0.001681  0.001632          -0.000487
# popularity_index               0.002246  0.000199          -0.000421
# green_space_ratio             -0.223997 -0.128067          -0.074506
# estimated_maintenance_cost     0.037225  0.371149           0.376379
# global_economic_index         -0.004486  0.004308           0.003214
#
#                             infrastructure_quality  neighborhood_crime_rate  \
# dim_m2                                    0.011522                -0.000547
# n_rooms                                   0.001110                -0.000970
# floor_no                                 -0.035104                -0.002542
# floor_max                                -0.075598                 0.001806
# year_built                               -0.921149                -0.003277
# dist_centre                              -0.302203                -0.006379
# n_poi                                     0.315429                 0.003857
# dist_sch                                 -0.224365                -0.003669
# dist_clinic                              -0.215063                -0.002069
# dist_post                                -0.201274                -0.001685
# dist_kind                                -0.105093                 0.000221
# dist_rest                                -0.143690                -0.001941
# dist_uni                                 -0.309884                -0.005784
# dist_pharma                              -0.171352                -0.001681
# price_z                                  -0.143008                 0.001632
# market_volatility                        -0.104882                -0.000487
# infrastructure_quality                    1.000000                 0.002162
# neighborhood_crime_rate                   0.002162                 1.000000
# popularity_index                          0.003754                 0.000993
# green_space_ratio                         0.256683                 0.002415
# estimated_maintenance_cost                0.007570                 0.002826
# global_economic_index                    -0.000161                -0.000128
#
#                             popularity_index  green_space_ratio  \
# dim_m2                             -0.000080          -0.042473
# n_rooms                            -0.002391          -0.048711
# floor_no                           -0.002836           0.023672
# floor_max                          -0.003839           0.021144
# year_built                         -0.003161          -0.278373
# dist_centre                         0.005492          -0.826239
# n_poi                              -0.001391           0.311658
# dist_sch                           -0.000168          -0.276299
# dist_clinic                        -0.000421          -0.383959
# dist_post                           0.000995          -0.231928
# dist_kind                          -0.003980          -0.136197
# dist_rest                           0.000182          -0.198765
# dist_uni                            0.005220          -0.485289
# dist_pharma                         0.002246          -0.223997
# price_z                             0.000199          -0.128067
# market_volatility                  -0.000421          -0.074506
# infrastructure_quality              0.003754           0.256683
# neighborhood_crime_rate             0.000993           0.002415
# popularity_index                    1.000000          -0.001974
# green_space_ratio                  -0.001974           1.000000
# estimated_maintenance_cost          0.002313          -0.028111
# global_economic_index              -0.000005          -0.010668
#
#                             estimated_maintenance_cost  global_economic_index
# dim_m2                                        0.692743              -0.016099
# n_rooms                                       0.529219              -0.013060
# floor_no                                     -0.047334               0.009317
# floor_max                                    -0.087672               0.012445
# year_built                                   -0.006414               0.000248
# dist_centre                                   0.030678               0.012266
# n_poi                                         0.018242              -0.004696
# dist_sch                                      0.042037              -0.001473
# dist_clinic                                   0.009800               0.005948
# dist_post                                     0.034485              -0.002376
# dist_kind                                     0.045157              -0.005224
# dist_rest                                     0.021819              -0.002057
# dist_uni                                      0.028777               0.002387
# dist_pharma                                   0.037225              -0.004486
# price_z                                       0.371149               0.004308
# market_volatility                             0.376379               0.003214
# infrastructure_quality                        0.007570              -0.000161
# neighborhood_crime_rate                       0.002826              -0.000128
# popularity_index                              0.002313              -0.000005
# green_space_ratio                            -0.028111              -0.010668
# estimated_maintenance_cost                    1.000000              -0.012754
# global_economic_index                        -0.012754               1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(
    numeric_correlations,
    annot = True,
    cmap = 'coolwarm',
    fmt = '.2f',
    linewidth = 0.5
)
# Out:
# <Axes: >

# %%
mask = np.triu(np.ones_like(numeric_correlations, dtype = bool))
correlations_with_y = numeric_correlations['price_z'].sort_values(
    ascending = False
)
ordered_columns = correlations_with_y.index

numeric_correlations = numeric_correlations[ordered_columns].loc[ordered_columns]

my_cmap = sns.diverging_palette(250, 10, as_cmap = True)

plt.figure(figsize = (10, 10))
sns.heatmap(
    numeric_correlations,
    annot = True,
    cmap = my_cmap,
    mask = mask,
    fmt = '.2f',
    linewidths = 0.5,
    center = 0
)
# Out:
# <Axes: >

# %%
to_keep_numeric_cols = ['market_volatility', 'dim_m2', 'n_rooms', 
                        'estimated_maintenance_cost', 'year_built', 
                        'n_poi', 'dist_centre', 'green_space_ratio', 
                        'infrastructure_quality']

# %%
rows_to_plot = pd.concat([
    numeric_correlations.iloc[0:6],       # first 6 rows
    numeric_correlations.iloc[-2:]        # last 2 rows
])

plt.figure(figsize=(6, 5))
sns.heatmap(
    rows_to_plot.iloc[:, 0:6],  # first 6 columns (adjust if needed)
    annot=True,
    cmap=my_cmap,
    fmt='.2f',
    linewidths=0.5,
    center=0
)
# Out:
# <Axes: >

# %% [markdown]
# order specifies the degree of the polynomial fit:
#
# order=1 → linear fit
#
# order=2 → quadratic fit
#
# order=3 → cubic fit
#
# …and so on.
#
# It controls the curve of the regression line.

# %%
sns.set_theme()

plt.figure(figsize=(10, 6))
sns.regplot(
    x = 'market_volatility',
    y = 'price_z',
    data = df_train.sample(1000, random_state = 123), # to select sub sample
    scatter_kws = {'color' : 'blue'},
    line_kws = {'color': 'red'},
    order = 3, # higher order polynomial regression to capture nonlinear trends
    ci = 95, # confidence interval: 95%
    marker = 'x'
)

plt.title('Relationship between X: Market Volatility and Y: price')
plt.xlabel('market_volatility')
plt.ylabel('price_z')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x = 'dim_m2',
    y = 'price_z',
    data = df_train.sample(1000, random_state = 123), # to select sub sample
    scatter_kws = {'color' : 'blue'},
    line_kws = {'color': 'red'},
    order = 1, # higher order polynomial regression to capture nonlinear trends
    ci = 95, # confidence interval: 95%
    marker = 'x'
)

plt.title('Relationship between X: dim_m2 and Y: price')
plt.xlabel('dim_m2')
plt.ylabel('price_z')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x = 'n_rooms',
    y = 'price_z',
    data = df_train, # to select sub sample
    scatter_kws = {'color' : 'blue'},
    line_kws = {'color': 'red'},
    # order = 1, # higher order polynomial regression to capture nonlinear trends
    ci = 95, # confidence interval: 95%
    marker = 'x'
    # x_estimator=np.mean
)

plt.title('Relationship between X: n_rooms and Y: price')
plt.xlabel('n_rooms')
plt.ylabel('price_z')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x = 'estimated_maintenance_cost',
    y = 'price_z',
    data = df_train.sample(10000, random_state = 123), # to select sub sample
    scatter_kws = {'color' : 'blue'},
    line_kws = {'color': 'red'},
    order = 1, # higher order polynomial regression to capture nonlinear trends
    ci = 95, # confidence interval: 95%
    marker = 'x'
)

plt.title('Relationship between X: Market Volatility and Y: price')
plt.xlabel('market_volatility')
plt.ylabel('price_z')
plt.show()
